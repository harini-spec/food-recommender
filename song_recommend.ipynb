# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('tcc_ceds_music.csv')

df
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
size = len(df)+1
df.insert(0, 'song_id', range(1, size))
df
# Out:
#        song_id  Unnamed: 0           artist_name  \
# 0            1           0                mukesh
# 1            2           4         frankie laine
# 2            3           6           johnnie ray
# 3            4          10           pérez prado
# 4            5          12  giorgos papadopoulos
# ...        ...         ...                   ...
# 28367    28368       82447               mack 10
# 28368    28369       82448                m.o.p.
# 28369    28370       82449                  nine
# 28370    28371       82450            will smith
# 28371    28372       82451                 jeezy
#
#                           track_name  release_date    genre  \
# 0               mohabbat bhi jhoothi          1950      pop
# 1                          i believe          1950      pop
# 2                                cry          1950      pop
# 3                           patricia          1950      pop
# 4                 apopse eida oneiro          1950      pop
# ...

# %%
df = df[['song_id','artist_name','release_date','genre', 'topic', 'age', 'track_name']]
# 'dating', 'violence', 'night/time', 'shake the audience', 'family/gospel', 'romantic', 'communication', 'music', 'obscene', 'movement/places', 'light/visual perceptions', 'energy', 'valence', 'like/girls', 'family/spiritual', 'sadness', 'feelings', 'danceability', 'loudness', 'acousticness', 'instrumentalness'

# %%
df
# Out:
#        song_id           artist_name  release_date    genre       topic  \
# 0            1                mukesh          1950      pop     sadness
# 1            2         frankie laine          1950      pop  world/life
# 2            3           johnnie ray          1950      pop       music
# 3            4           pérez prado          1950      pop    romantic
# 4            5  giorgos papadopoulos          1950      pop    romantic
# ...        ...                   ...           ...      ...         ...
# 28367    28368               mack 10          2019  hip hop     obscene
# 28368    28369                m.o.p.          2019  hip hop     obscene
# 28369    28370                  nine          2019  hip hop     obscene
# 28370    28371            will smith          2019  hip hop     obscene
# 28371    28372                 jeezy          2019  hip hop     obscene
#
#             age                     track_name
# 0      1.000000           mohabbat bhi jhoothi
# ...

# %%
df['release_date'] = df['release_date'].astype("str")
# Out:
# /tmp/ipykernel_5107/3381559587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_date'] = df['release_date'].astype("str")

# %%
df["tags"] = df["topic"] +","+ df["genre"] +","+ df["release_date"]
df["tags"]
# Out:
# /tmp/ipykernel_5107/3858361007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"] = df["topic"] +","+ df["genre"] +","+ df["release_date"]
# 0            sadness,pop,1950
# 1         world/life,pop,1950
# 2              music,pop,1950
# 3           romantic,pop,1950
# 4           romantic,pop,1950
#                  ...
# 28367    obscene,hip hop,2019
# 28368    obscene,hip hop,2019
# 28369    obscene,hip hop,2019
# 28370    obscene,hip hop,2019
# 28371    obscene,hip hop,2019
# Name: tags, Length: 28372, dtype: object

# %%
# df = df.head(500)
df = df.head(1000)

# %%
# new_df = df[["artist_name", "track_name", "age", "tags"]]

# %%
from sklearn.feature_extraction.text import CountVectorizer
count = CountVectorizer(stop_words='english')

count_matrix = count.fit_transform(df['tags'])

from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

indices_from_title = pd.Series(df.index, index=df['track_name'])
indices_from_food_id = pd.Series(df.index, index=df['song_id'])

# %%
def get_recommendations(title="", cosine_sim=cosine_sim, idx=-1):
    if idx == -1 and title != "":
        idx = indices_from_title[title]

    sim_scores = list(enumerate(cosine_sim[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    sim_scores = sim_scores[1:3]

    song_indices = [i[0] for i in sim_scores]

    return song_indices

# %%
df1 = df.loc[get_recommendations(title="patricia")]

# %%
df1
# Out:
#    song_id           artist_name release_date genre     topic  age  \
# 4        5  giorgos papadopoulos         1950   pop  romantic  1.0
# 8        9   stélios kazantzídis         1950   pop  romantic  1.0
#
#                  track_name               tags
# 4        apopse eida oneiro  romantic,pop,1950
# 8  klapse me mana klapse me  romantic,pop,1950

# %%
df1['track_name']
# Out:
# 4          apopse eida oneiro
# 8    klapse me mana klapse me
# Name: track_name, dtype: object

# %%
df1['track_name'].values.tolist()
# Out:
# ['apopse eida oneiro', 'klapse me mana klapse me']
